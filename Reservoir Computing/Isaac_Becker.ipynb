# %%
from ResComp import *
from res_specialization import *

# %%
t, test_t, u = lorenz_equ(x0=[-20, 10, -.5], begin=0, end=60, timesteps=60000)

# %%
plt.plot(u(t).T)

# %%
rc = ResComp(6,6, res_sz=200)
err = rc.fit(t,robot_u)
err
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-291c99b157bb> in <module>
#       1 rc = ResComp(6,6, res_sz=200)
# ----> 2 err = rc.fit(t,robot_u)
#       3 err
#
# ~/Code/NetworkResearch/Reservoir Computing/ResComp.py in fit(self, t, u)
#      71         """
#      72
# ---> 73         driven_states    = self.drive(t,u)
#      74         true_states      = u(t).T
#      75
#
# ~/Code/NetworkResearch/Reservoir Computing/ResComp.py in drive(self, t, u)
#      58
#      59         r_0    = self.state_0
# ---> 60         states = integrate.odeint(res_f,r_0,t)
#      61         self.state_0 = states[-1]
#      62         return states
#
# ...

# %%
x0=[-20, 10, -.5]
pred = rc.predict(t, u_0=x0)

# %%
plt.plot(pred.T[10000:])

# %%
data = np.random.rand(7836,6)
t = [n for n in range(7836)]

# %%
np.floor(10*t[10])
# Out:
# 1.0

# %%
def robot_u(t):
    return data[t]

# %%
u(.2)
# Out:
# array([-19.36834271,  -6.816246  ,  50.43751927])

# %%
robot_u(2)
# Out:
# array([0.5688376 , 0.88592626, 0.50385579, 0.32267881, 0.58222154,
#        0.40402964])

# %%
robot_u(t)
# Out:
# array([[0.5966965 , 0.59075858, 0.59439371, 0.31366915, 0.23625073,
#         0.04553077],
#        [0.49698718, 0.68171504, 0.38611138, 0.93783094, 0.33679815,
#         0.72959935],
#        [0.5688376 , 0.88592626, 0.50385579, 0.32267881, 0.58222154,
#         0.40402964],
#        ...,
#        [0.04937977, 0.91151327, 0.33206961, 0.71844375, 0.827569  ,
#         0.19452618],
#        [0.48940948, 0.01235035, 0.64135904, 0.71131058, 0.20346574,
#         0.92791658],
#        [0.50935472, 0.47625347, 0.57640327, 0.44323004, 0.48361782,
#         0.92025298]])
